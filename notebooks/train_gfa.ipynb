# %% [markdown]
# # CLIP4CAD-GFA Training Notebook
#
# This notebook provides a persistent training environment that keeps the 204GB dataset in memory between runs.
#
# ## Key Benefits
# - **Load data ONCE** (~5 min) and keep it in RAM
# - **Fast iteration** - Restart training instantly
# - **No memory overflow** - Using `num_workers=0` since data is in RAM
#
# ## Usage
# 1. Run Cells 1-5 once to load data and initialize model (~5 min)
# 2. Run Cell 6 to start/restart training (instant!)
# 3. Use Cell 7-9 for resuming, validation, or monitoring

# %% [markdown]
# ## Cell 1: Imports & Setup

# %%
import sys
from pathlib import Path

# Add project root to path
sys.path.insert(0, 'D:/Defect_Det/MMCAD/MMCAD')

import torch
from omegaconf import OmegaConf
from clip4cad.models.clip4cad_gfa import CLIP4CAD_GFA
from clip4cad.data.gfa_dataset import GFAMappedDataset
from clip4cad.training.gfa_trainer import GFATrainer

print("✓ Imports loaded successfully")
print(f"✓ PyTorch version: {torch.__version__}")
print(f"✓ CUDA available: {torch.cuda.is_available()}")
# Out:
# ✓ Imports loaded successfully
# ✓ PyTorch version: 2.5.1+cu121
# ✓ CUDA available: True

# %% [markdown]
# ## Cell 2: Configuration
#
# Configure paths, hyperparameters, and output directory.
#
# **CRITICAL**: `num_workers=0` because all data is loaded into RAM (no need for worker processes)

# %%
# Paths
data_root = Path("d:/Defect_Det/MMCAD/data")
pc_file = "c:/Users/User/Desktop/pc_embeddings_full.h5"
brep_file = "c:/Users/User/Desktop/brep_features.h5"
text_file = "c:/Users/User/Desktop/text_embeddings.h5"
output_dir = Path("outputs/gfa_111k/test")
output_dir.mkdir(parents=True, exist_ok=True)

# Load config
config = OmegaConf.load("d:/Defect_Det/MMCAD/MMCAD/configs/model/clip4cad_gfa.yaml")

# Override training settings
config.training.batch_size = 512
config.training.num_workers = 0  # CRITICAL: No workers since data in RAM!
config.training.num_epochs_stage1 = 15
config.training.num_epochs_stage2 = 20

# Save config
OmegaConf.save(config, output_dir / "config.yaml")

print("✓ Configuration loaded")
print(f"  - Batch size: {config.training.batch_size}")
print(f"  - Num workers: {config.training.num_workers}")
print(f"  - Stage 1 epochs: {config.training.num_epochs_stage1}")
print(f"  - Stage 2 epochs: {config.training.num_epochs_stage2}")
print(f"  - Output dir: {output_dir}")
# Out:
# ✓ Configuration loaded
#   - Batch size: 512
#   - Num workers: 0
#   - Stage 1 epochs: 15
#   - Stage 2 epochs: 20
#   - Output dir: outputs\gfa_111k\test

# %% [markdown]
# ## Cell 3: Load Datasets (RUN ONCE, ~5 min)
#
# **This cell loads 204GB of data into RAM**
# **⚠️ Takes ~5 minutes, but only run ONCE!**
#
# After running this cell:
# - Training data stays in memory
# - Can restart training instantly by re-running Cell 6
# - Don't re-run this cell unless you restart the kernel

# %%
print("Loading datasets (this takes ~5 min, but only once!)...")
print("="*60)

# Train dataset - LOAD TO RAM
print("\n[1/2] Loading TRAIN dataset to RAM...")
train_dataset = GFAMappedDataset(
    data_root=str(data_root),
    split="train",
    pc_file=pc_file,
    text_file=text_file,
    brep_file=brep_file,
    num_rotations=1,
    load_to_memory=True,  # Load 111k samples to RAM
    use_live_text=False,
)
print(f"✓ Train dataset loaded: {len(train_dataset):,} samples in RAM")

# Val dataset - KEEP ON DISK (saves RAM)
print("\n[2/2] Loading VAL dataset (on disk)...")
val_dataset = GFAMappedDataset(
    data_root=str(data_root),
    split="val",
    pc_file=pc_file,
    text_file=text_file,
    brep_file=brep_file,
    num_rotations=1,
    load_to_memory=False,  # Val stays on disk (saves RAM)
    use_live_text=False,
)
print(f"✓ Val dataset loaded: {len(val_dataset):,} samples on disk")

print("\n" + "="*60)
print("✓ DATASETS READY!")
print(f"  - Train: {len(train_dataset):,} samples in RAM")
print(f"  - Val: {len(val_dataset):,} samples on disk")
print("\n⚠️  Do NOT re-run this cell unless you restart the kernel!")
print("="*60)
# Out:
# Loading datasets (this takes ~5 min, but only once!)...
# ...
#
# [1/2] Loading TRAIN dataset to RAM...
#   Loading train data to memory (B-Rep + PC + Text)...
#     Loading B-Rep (3GB)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 6
#       4 # Train dataset - LOAD TO RAM
#       5 print("\n[1/2] Loading TRAIN dataset to RAM...")
# ----> 6 train_dataset = GFAMappedDataset(
#       7     data_root=str(data_root),
#       8     split="train",
#       9     pc_file=pc_file,
#      10     text_file=text_file,
#      11     brep_file=brep_file,
#      12     num_rotations=1,
#      13     load_to_memory=True,  # Load 111k samples to RAM
#      14     use_live_text=False,
#      15 )
#      16 print(f"✓ Train dataset loaded: {len(train_dataset):,} samples in RAM")
#      18 # Val dataset - KEEP ON DISK (saves RAM)
#
# ...

# %% [markdown]
# ## Cell 4: Initialize Model
#
# Create the CLIP4CAD-GFA model and move it to GPU.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Create model
model = CLIP4CAD_GFA(config)

print("\n✓ Model initialized")
print(f"  - Total parameters: {model.count_parameters():,}")
print(f"  - Trainable parameters: {model.count_parameters(trainable_only=True):,}")
# Out:
# Using device: cuda
#
# ✓ Model initialized
#   - Total parameters: 3,168,771
#   - Trainable parameters: 3,168,771

# %% [markdown]
# ## Cell 5: Create Trainer
#
# Initialize the GFA trainer with datasets, model, and configuration.

# %%
trainer = GFATrainer(
    model=model,
    train_dataset=train_dataset,
    val_dataset=val_dataset,
    config=config.training,
    device=device,
    output_dir=str(output_dir),
)

print("✓ Trainer initialized")
print(f"  - Output directory: {output_dir}")
print(f"  - Device: {device}")
print("\n✓ Ready to train! Run Cell 6 to start training.")
# Out:
# ✓ Trainer initialized
#   - Output directory: outputs\gfa_111k\test
#   - Device: cuda
#
# ✓ Ready to train! Run Cell 6 to start training.

# %%
# Cell 5.5: Load from Best Checkpoint                                                                                                                                                                                                        checkpoint_path = Path("notebooks/outputs/gfa_111k/checkpoint_best.pt")
checkpoint_path = Path("d:/Defect_Det/MMCAD/MMCAD/notebooks/outputs/gfa_111k/checkpoint_best.pt")
if checkpoint_path.exists():
    print(f"Loading checkpoint: {checkpoint_path}")
    checkpoint = torch.load(checkpoint_path, map_location=device)

    # Load model state
    model.load_state_dict(checkpoint['model_state_dict'])
    trainer.resume(str(checkpoint_path))
    print(f"✓ Will continue from epoch {trainer.current_epoch + 1}")
    
else:
    print(f"No checkpoint found at {checkpoint_path}")
# Out:
# Loading checkpoint: d:\Defect_Det\MMCAD\MMCAD\notebooks\outputs\gfa_111k\checkpoint_best.pt
# ...

# %% [markdown]
# ## Cell 6: Train (Re-run this cell to restart training)
#
# **Start or restart training from scratch**
#
# This cell can be run multiple times:
# - Data stays in RAM (no reload needed!)
# - Model re-initializes from scratch
# - To resume from checkpoint, use Cell 7 instead

# %%
# Optional: Resume from checkpoint
# Uncomment the lines below to resume from a specific checkpoint
# checkpoint_path = output_dir / "checkpoint_epoch5.pt"
# if checkpoint_path.exists():
#     trainer.load_checkpoint(str(checkpoint_path))
#     print(f"✓ Resumed from {checkpoint_path}")

print("Starting training...")
print("="*60)
trainer.train()
print("="*60)
print("✓ Training completed!")
# Out:
# Starting training...
# ...
# CLIP4CAD-GFA Training
# ...
# Total epochs: 35
# Stage 1: 15 epochs (grounding)
# Stage 2: 20 epochs (alignment)
# Batch size: 512
# Learning rate: 3e-05
# Checkpoint every: 5 epochs
# Trainable parameters: 3,168,771
# ...
# Epoch 1 (Stage 1):   0%|          | 0/216 [00:00<?, ?it/s]D:\Defect_Det/MMCAD/MMCAD\clip4cad\training\gfa_trainer.py:335: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 1 (Stage 1):   0%|          | 1/216 [00:02<08:45,  2.44s/it, loss=4.970, G=6.499, L=6.212, C=0.984, D=0.015, cf=0.000, lr=4.6e-08]
#   [Conf] min=0.438 max=0.501 mean=0.469 active=12.0/12
# Epoch 1 (Stage 1):   6%|▌         | 13/216 [00:09<02:24,  1.41it/s, loss=4.959, G=6.500, L=6.195, C=0.979, D=0.014, cf=0.000, lr=6.0e-07]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %% [markdown]
# ## Cell 7: Resume Training from Checkpoint (Optional)
#
# Resume training from a specific checkpoint epoch.

# %%
# Specify the checkpoint to resume from
checkpoint_epoch = 10  # Change this to the epoch you want to resume from
checkpoint_path = output_dir / f"checkpoint_epoch{checkpoint_epoch}.pt"

if checkpoint_path.exists():
    print(f"Resuming from {checkpoint_path}...")
    trainer.load_checkpoint(str(checkpoint_path))
    print(f"✓ Checkpoint loaded from epoch {checkpoint_epoch}")
    
    print("\nRestarting training...")
    print("="*60)
    trainer.train()
    print("="*60)
    print("✓ Training completed!")
else:
    print(f"❌ Checkpoint not found: {checkpoint_path}")
    print(f"\nAvailable checkpoints:")
    checkpoints = sorted(output_dir.glob("checkpoint_epoch*.pt"))
    if checkpoints:
        for ckpt in checkpoints:
            print(f"  - {ckpt.name}")
    else:
        print("  - No checkpoints found")

# %% [markdown]
# ## Cell 8: Quick Validation (Optional)
#
# Run validation without training to check model performance.

# %%
print("Running validation...")
val_metrics = trainer.validate()

print("\n✓ Validation Results:")
print("="*60)
for key, value in val_metrics.items():
    if isinstance(value, float):
        print(f"  {key}: {value:.4f}")
    else:
        print(f"  {key}: {value}")
print("="*60)

# %% [markdown]
# ## Cell 9: Check RAM Usage (Optional)
#
# Monitor memory usage to ensure no memory leaks.

# %%
import psutil
import gc

# Force garbage collection
gc.collect()
torch.cuda.empty_cache()

# Check system RAM
process = psutil.Process()
ram_gb = process.memory_info().rss / 1e9
total_ram = psutil.virtual_memory().total / 1e9
available_ram = psutil.virtual_memory().available / 1e9

print("Memory Usage:")
print("="*60)
print(f"  Process RAM: {ram_gb:.1f} GB")
print(f"  Total System RAM: {total_ram:.1f} GB")
print(f"  Available RAM: {available_ram:.1f} GB")
print(f"  RAM Usage: {(total_ram - available_ram) / total_ram * 100:.1f}%")

# Check GPU memory if available
if torch.cuda.is_available():
    gpu_allocated = torch.cuda.memory_allocated() / 1e9
    gpu_reserved = torch.cuda.memory_reserved() / 1e9
    gpu_total = torch.cuda.get_device_properties(0).total_memory / 1e9
    
    print(f"\nGPU Memory:")
    print(f"  Allocated: {gpu_allocated:.1f} GB")
    print(f"  Reserved: {gpu_reserved:.1f} GB")
    print(f"  Total: {gpu_total:.1f} GB")
    print(f"  Usage: {gpu_allocated / gpu_total * 100:.1f}%")

print("="*60)

# %%
# Reload model module to pick up code changes (no data reload needed!)
import importlib
from clip4cad.models import clip4cad_gfa

# Reload the module with the fix
importlib.reload(clip4cad_gfa)

# Re-import the class
from clip4cad.models.clip4cad_gfa import CLIP4CAD_GFA
from clip4cad.training import gfa_trainer                                                                                                                                                                                                  
importlib.reload(gfa_trainer)
from clip4cad.training.gfa_trainer import GFATrainer

from clip4cad.training import hard_negative_mining                                                                                                                                                                                         
importlib.reload(hard_negative_mining)
print("✓ Model code reloaded with confidence clamp fix")
# Out:
# ✓ Model code reloaded with confidence clamp fix

# %%
# =============================================================================                                         # MULTI-CHECKPOINT EVALUATION (Load data once, evaluate many checkpoints)
# =============================================================================                                       
import torch
import torch.nn.functional as F
import numpy as np
import json
import gc
from pathlib import Path
from torch.utils.data import DataLoader
from tqdm.auto import tqdm
from omegaconf import OmegaConf
from clip4cad.data.gfa_dataset import GFAMappedDataset, gfa_collate_fn
from clip4cad.models.clip4cad_gfa import CLIP4CAD_GFA

# -----------------------------------------------------------------------------
# Configuration
# -----------------------------------------------------------------------------
EVAL_CONFIG = {
    "checkpoints": [
        "outputs/gfa_111k/checkpoint_epoch30.pt",
        "outputs/gfa_111k/checkpoint_epoch25.pt",
    ],
    "splits": ["val", "test"],
    "batch_size": 64,
    "k_values": [1, 5, 10],
    "output_dir": "outputs/evaluation",

    # Paths
    "data_root": "d:/Defect_Det/MMCAD/data",
    "mapping_dir": "d:/Defect_Det/MMCAD/data/aligned",
    "text_splits_dir": "C:/Users/User/Desktop/text_splits",
    "pc_file": None,
}

device = "cuda" if torch.cuda.is_available() else "cpu"

# -----------------------------------------------------------------------------
# Helper Functions
# -----------------------------------------------------------------------------
def compute_rankings(query_emb, gallery_emb, k=10, batch_size=128):
    n = query_emb.shape[0]
    rankings = torch.zeros(n, k, dtype=torch.long)
    gallery_gpu = gallery_emb.to(device)
    for i in range(0, n, batch_size):
        j = min(i + batch_size, n)
        sim = torch.mm(query_emb[i:j].to(device), gallery_gpu.T)
        _, top_k = torch.topk(sim, k=k, dim=1)
        rankings[i:j] = top_k.cpu()
    return rankings

def compute_metrics(rankings, ids, k_values):
    n = len(ids)
    results = {}
    for k in k_values:
        hits, ap_sum = 0, 0.0
        for i in range(n):
            qid = str(ids[i])
            for rank, idx in enumerate(rankings[i, :k]):
                if str(ids[idx]) == qid:
                    hits += 1
                    ap_sum += 1.0 / (rank + 1)
                    break
        results[f"R@{k}"] = hits / n
        results[f"mAP@{k}"] = ap_sum / n
    return results

# %%
# -----------------------------------------------------------------------------
# STEP 1: Load datasets ONCE
# -----------------------------------------------------------------------------
print("="*70)
print("STEP 1: Loading datasets (once)")
print("="*70)

datasets = {}
loaders = {}

for split in EVAL_CONFIG["splits"]:
    print(f"\nLoading {split}...")
    text_file = Path(EVAL_CONFIG["text_splits_dir"]) / f"{split}_text_embeddings.h5"

    datasets[split] = GFAMappedDataset(
        data_root=EVAL_CONFIG["data_root"],
        split=split,
        pc_file=EVAL_CONFIG.get("pc_file"),
        text_file=str(text_file),
        mapping_dir=EVAL_CONFIG["mapping_dir"],
        num_rotations=1,
        load_to_memory=True,
    )

    loaders[split] = DataLoader(
        datasets[split],
        batch_size=EVAL_CONFIG["batch_size"],
        shuffle=False,
        num_workers=0,
        pin_memory=True,
        collate_fn=gfa_collate_fn,
    )
    print(f"  ✓ {split}: {len(datasets[split])} samples")

print("\n✓ All datasets loaded!")
# Out:
# ...
# STEP 1: Loading datasets (once)
# ...
#
# Loading val...
#   Loading val data to memory (B-Rep + PC + Text)...
#     Loading B-Rep (3GB)...
#     Loading PC (50GB)...
#     Loading Text from: c:\Users\User\Desktop\text_splits\val_text_embeddings.h5
#     ✓ Text loaded: 26.2GB in 26.6s
#   ✓ Loaded 16638 samples: 30.5GB in RAM (B-Rep + PC + Text)
# GFAMappedDataset: val with 16638 samples (in memory)
#   ✓ val: 16638 samples
#
# Loading test...
#   Loading test data to memory (B-Rep + PC + Text)...
#     Loading B-Rep (3GB)...
#     Loading PC (50GB)...
#     Loading Text from: c:\Users\User\Desktop\text_splits\test_text_embeddings.h5
#     ✓ Text loaded: 26.2GB in 48.6s
#   ✓ Loaded 16639 samples: 30.5GB in RAM (B-Rep + PC + Text)
# GFAMappedDataset: test with 16639 samples (in memory)
#   ✓ test: 16639 samples
#
# ✓ All datasets loaded!

# %%
# -----------------------------------------------------------------------------
# STEP 2: Evaluate each checkpoint
# -----------------------------------------------------------------------------
print("\n" + "="*70)
print("STEP 2: Evaluating checkpoints")
print("="*70)

all_results = {}

for ckpt_path in EVAL_CONFIG["checkpoints"]:
    ckpt_name = Path(ckpt_path).stem
    print(f"\n{'─'*70}")
    print(f"Checkpoint: {ckpt_name}")
    print(f"{'─'*70}")

    # Load model
    ckpt = torch.load(ckpt_path, map_location=device, weights_only=False)

    default_cfg = Path("../configs/model/clip4cad_gfa.yaml")
    if not default_cfg.exists():
        default_cfg = Path("configs/model/clip4cad_gfa.yaml")
    config = OmegaConf.load(default_cfg)
    if "config" in ckpt:
        config = OmegaConf.merge(config, OmegaConf.create(ckpt["config"]))

    _model = CLIP4CAD_GFA(config)
    _model.load_state_dict(ckpt["model_state_dict"], strict=True)
    _model = _model.to(device).eval()

    weight_sum = list(_model.parameters())[0].data.sum().item()
    print(f"  Epoch: {ckpt.get('epoch', '?')}, Checksum: {weight_sum:.4f}")

    # Generate embeddings function (captures _model)
    @torch.no_grad()
    def gen_emb(loader):
        text_e, brep_e, pc_e, ids = [], [], [], []
        for batch in tqdm(loader, desc="  Embeddings", leave=False):
            ids.extend(batch["sample_id"])
            for k in batch:
                if isinstance(batch[k], torch.Tensor) and batch[k].dtype == torch.float16:
                    batch[k] = batch[k].float()
            out = _model(batch)
            text_e.append(F.normalize(out["z_text"].float(), p=2, dim=-1).cpu())
            if "z_brep" in out:
                brep_e.append(F.normalize(out["z_brep"].float(), p=2, dim=-1).cpu())
            if "z_pc" in out:
                pc_e.append(F.normalize(out["z_pc"].float(), p=2, dim=-1).cpu())
        return {
            "text": torch.cat(text_e),
            "brep": torch.cat(brep_e) if brep_e else None,
            "pc": torch.cat(pc_e) if pc_e else None,
            "ids": ids
        }

    ckpt_results = {}

    for split in EVAL_CONFIG["splits"]:
        emb = gen_emb(loaders[split])
        ids = emb["ids"]
        k_max = max(EVAL_CONFIG["k_values"])

        tasks = [
            ("Text→BRep", emb["text"], emb["brep"]),
            ("Text→PC", emb["text"], emb["pc"]),
            ("PC→BRep", emb["pc"], emb["brep"]),
            ("BRep→PC", emb["brep"], emb["pc"]),
        ]

        split_results = {}
        for task, q, g in tasks:
            if q is None or g is None:
                continue
            rankings = compute_rankings(q, g, k_max)
            split_results[task] = compute_metrics(rankings, ids, EVAL_CONFIG["k_values"])

        ckpt_results[split] = split_results

        # Print summary for this split
        print(f"\n  {split.upper()}:")
        print(f"  {'Task':<12} {'R@1':>7} {'R@5':>7} {'R@10':>7} {'mAP@1':>7} {'mAP@5':>7} {'mAP@10':>7}")
        for task, m in split_results.items():
            print(f"  {task:<12} {m['R@1']:>7.4f} {m['R@5']:>7.4f} {m['R@10']:>7.4f} "
                f"{m['mAP@1']:>7.4f} {m['mAP@5']:>7.4f} {m['mAP@10']:>7.4f}")

    all_results[ckpt_name] = ckpt_results

    # Cleanup model
    del _model, ckpt
    gc.collect()
    torch.cuda.empty_cache()
# Out:
# ...
# STEP 2: Evaluating checkpoints
# ...
#
# ──────────────────────────────────────────────────────────────────────
# Checkpoint: checkpoint_epoch30
# ──────────────────────────────────────────────────────────────────────
#   Epoch: 30, Checksum: 0.3637
#   Embeddings:   0%|          | 0/260 [00:00<?, ?it/s]
#   VAL:
#   Task             R@1     R@5    R@10   mAP@1   mAP@5  mAP@10
#   Text→BRep     0.3761  0.6709  0.7658  0.3761  0.4892  0.5020
#   Text→PC       0.3412  0.6651  0.7757  0.3412  0.4636  0.4786
#   PC→BRep       0.1555  0.3850  0.5059  0.1555  0.2372  0.2534
#   BRep→PC       0.1143  0.3072  0.4187  0.1143  0.1822  0.1971
#   Embeddings:   0%|          | 0/260 [00:00<?, ?it/s]
#   TEST:
#   Task             R@1     R@5    R@10   mAP@1   mAP@5  mAP@10
#   Text→BRep     0.3772  0.6723  0.7657  0.3772  0.4891  0.5018
#   Text→PC       0.3418  0.6645  0.7741  0.3418  0.4622  0.4770
#   PC→BRep       0.1502  0.3793  0.5041  0.1502  0.2315  0.2481
# ...

# %%
# -----------------------------------------------------------------------------
# STEP 3: Summary comparison table
# -----------------------------------------------------------------------------
print("\n" + "="*70)
print("SUMMARY: Text→BRep R@1 across checkpoints")
print("="*70)
print(f"{'Checkpoint':<30} {'Val R@1':>10} {'Test R@1':>10}")
print("-"*50)
for ckpt_name, results in all_results.items():
    val_r1 = results.get("val", {}).get("Text→BRep", {}).get("R@1", 0)
    test_r1 = results.get("test", {}).get("Text→BRep", {}).get("R@1", 0)
    print(f"{ckpt_name:<30} {val_r1:>10.4f} {test_r1:>10.4f}")

# Save results
output_dir = Path(EVAL_CONFIG["output_dir"])
output_dir.mkdir(parents=True, exist_ok=True)
with open(output_dir / "multi_checkpoint_eval.json", "w") as f:
    json.dump(all_results, f, indent=2)
print(f"\n✓ Results saved to: {output_dir / 'multi_checkpoint_eval.json'}")
# Out:
# ...
# SUMMARY: Text→BRep R@1 across checkpoints
# ...
# Checkpoint                        Val R@1   Test R@1
# --------------------------------------------------
# checkpoint_epoch10                 0.2144     0.2150
# checkpoint_epoch20                 0.3891     0.3901
#
# ✓ Results saved to: outputs\evaluation\multi_checkpoint_eval.json

# %%
# Cell 12: Ablation Training Setup
from clip4cad.ablations import AblationTrainer, ABLATION_TYPES
import matplotlib.pyplot as plt
import importlib
import clip4cad.ablations.trainer
importlib.reload(clip4cad.ablations.trainer)
from clip4cad.ablations import AblationTrainer

ABLATION_CONFIG = {
    "config_path": "../configs/model/clip4cad_gfa.yaml",
    "output_base": "outputs/ablations",
}
config.training.batch_size = 512
config.training.num_workers = 0  # CRITICAL: No workers since data in RAM!

print("Available ablations:")
for name, desc in ABLATION_TYPES.items():
    print(f"  {name}: {desc}")

print(f"\nUsing existing datasets:")
print(f"  Train: {len(train_dataset):,} samples")
print(f"  Val: {len(val_dataset):,} samples")
# Out:
# Available ablations:
#   baseline: Full model with all losses and learned confidence
#   no_consistency: Disable grounding consistency loss (λ_c=0)
#   global_only: Only global contrastive loss (no local/grounding)
#   no_confidence: Fixed uniform confidence (no learned weighting)
#
# Using existing datasets:
#   Train: 111,000 samples
#   Val: 16,638 samples

# %%
# Cell 13: Train a Single Ablation
ABLATION_TYPE = "no_consistency"  # Change to: "no_consistency", "global_only", "no_confidence"

trainer = AblationTrainer(
    ablation_type=ABLATION_TYPE,
      train_dataset=train_dataset,                                                                                                                                                                                                                 val_dataset=val_dataset,
      config_path=ABLATION_CONFIG["config_path"],
      output_dir=f"{ABLATION_CONFIG['output_base']}/{ABLATION_TYPE}",
      custom_config={"training": {"batch_size": 512}},  # Add this
  )


for epoch in range(trainer.total_epochs):
    metrics = trainer.train_epoch()
    print(f"Epoch {epoch+1:2d} | Loss: {metrics['total']:.4f} | G: {metrics['global']:.4f} | L: {metrics['local']:.4f} | C: {metrics['consistency']:.4f}")

    if (epoch + 1) % 5 == 0:
        val_metrics = trainer.validate()

trainer.save_history()
print(f"\nDone! Saved to: {trainer.output_dir}")
# Out:
# ...
# Ablation: no_consistency
# Description: Disable grounding consistency loss (λ_c=0)
# ...
#   lambda_consist: 0.0 (was 0.5)
#
# Training schedule:
#   Stage 1: 15 epochs
#   Stage 2: 20 epochs
#   Total: 35 epochs
#
# Creating model...
#   [Ablation] Using LEARNED confidence
#
# Loss weights:
#   lambda_global: 1.0
#   lambda_local: 0.5
#   lambda_consist: 0.0
#   lambda_diverse: 0.2
#   lambda_conf_reg: 0.1
#   lambda_global_stage1: 0.2
#
# Trainer initialized:
#   Ablation: no_consistency
#   Train samples: 111,000
#   Val samples: 16,638
#   Total epochs: 35 (stage1: 15, stage2: 20)
#   Output: outputs\ablations\no_consistency
# D:\Defect_Det/MMCAD/MMCAD\clip4cad\ablations\trainer.py:132: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = GradScaler()
# [no_consistency] Epoch 1/35 (S1):   0%|          | 0/216 [00:00<?, ?it/s]
# ...

# %%
# Full imports
from clip4cad.ablations.models import CLIP4CAD_GFA_Ablation
from clip4cad.ablations.configs import get_ablation_config
from clip4cad.losses.gfa_losses import GFALoss
from torch.cuda.amp import GradScaler, autocast
from torch.optim import AdamW
from torch.utils.data import DataLoader
from clip4cad.data.gfa_dataset import gfa_collate_fn
from tqdm import tqdm

# Setup
ABLATION_TYPE = "no_consistency"  # Change as needed
config = get_ablation_config("../configs/model/clip4cad_gfa.yaml", ABLATION_TYPE)
model = CLIP4CAD_GFA_Ablation(config).cuda()
criterion = GFALoss()
optimizer = AdamW(model.parameters(), lr=1e-4)
scaler = GradScaler()

loader = DataLoader(train_dataset, batch_size=512, shuffle=True,
                    num_workers=0, pin_memory=True, collate_fn=gfa_collate_fn)

# Training loop with monitoring
num_epochs = 35
stage = 1
stage1_epochs = 15

for epoch in range(num_epochs):
    # Stage transition
    if epoch == stage1_epochs:
        stage = 2
        for pg in optimizer.param_groups:
            pg['lr'] *= 0.5
        print(f"\n{'='*50}\nTransitioning to Stage 2\n{'='*50}")

    model.train()
    epoch_loss = 0
    epoch_global = 0
    epoch_local = 0
    epoch_consist = 0

    pbar = tqdm(loader, desc=f"Epoch {epoch+1}/{num_epochs} (S{stage})")
    for batch_idx, batch in enumerate(pbar):
        with autocast():
            outputs = model(batch)
            loss, loss_dict = criterion(outputs, stage=stage)

        optimizer.zero_grad()
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        # Accumulate
        epoch_loss += loss_dict['total']
        epoch_global += loss_dict['global']
        epoch_local += loss_dict['local']
        epoch_consist += loss_dict['consistency']

        # Update progress bar
        pbar.set_postfix({
            'loss': f"{loss_dict['total']:.3f}",
            'G': f"{loss_dict['global']:.3f}",
            'L': f"{loss_dict['local']:.3f}",
            'C': f"{loss_dict['consistency']:.3f}",
        })

    # Epoch summary
    n = len(loader)
    print(f"Epoch {epoch+1} | Loss: {epoch_loss/n:.4f} | G: {epoch_global/n:.4f} | L: {epoch_local/n:.4f} | C: {epoch_consist/n:.4f}")

print("\nTraining complete!")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_49664\3829193773.py:17: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
#   [Ablation] Using LEARNED confidence
# Epoch 1/35 (S1):   0%|          | 0/217 [00:00<?, ?it/s]C:\Users\User\AppData\Local\Temp\ipykernel_49664\3829193773.py:43: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 1/35 (S1): 100%|██████████| 217/217 [01:22<00:00,  2.64it/s, loss=1.081, G=4.841, L=0.070, C=0.028]
# Epoch 1 | Loss: 1.6042 | G: 6.0401 | L: 0.5851 | C: 0.0745
# Epoch 2/35 (S1): 100%|██████████| 217/217 [01:03<00:00,  3.40it/s, loss=0.714, G=3.144, L=0.030, C=0.012]
# Epoch 2 | Loss: 0.9008 | G: 4.0254 | L: 0.0464 | C: 0.0177
# Epoch 3/35 (S1): 100%|██████████| 217/217 [01:06<00:00,  3.27it/s, loss=0.599, G=2.617, L=0.018, C=0.007]
# ...

# %%
# Cell 15: Train All Ablations (Run this instead of Cell 14 if you want all at once)

ablation_trainers = {}
ablation_histories = {}

for abl_type in ABLATION_CONFIG["ablations_to_run"]:
    print(f"\n{'='*60}")
    print(f"Training ablation: {abl_type}")
    print(f"{'='*60}")

    # Create trainer
    trainer = AblationTrainer(
        ablation_type=abl_type,
        train_dataset=ablation_train_dataset,
        val_dataset=ablation_val_dataset,
        config_path=ABLATION_CONFIG["config_path"],
        output_dir=f"{ABLATION_CONFIG['output_base']}/{abl_type}",
        device="cuda",
    )

    # Train
    num_epochs = trainer.total_epochs
    for epoch in range(num_epochs):
        metrics = trainer.train_epoch()

        if (epoch + 1) % 5 == 0:
            print(f"Epoch {epoch+1:2d}/{num_epochs} | "
                f"Loss: {metrics['total']:.4f} | "
                f"G: {metrics['global']:.4f} | "
                f"L: {metrics['local']:.4f}")
            trainer.validate()

    # Save and store
    trainer.save_history()
    ablation_histories[abl_type] = trainer.get_history()
    ablation_trainers[abl_type] = trainer

    print(f"Completed {abl_type}!")

print("\n" + "="*60)
print("All ablations complete!")
print("="*60)

# %%
# Cell 16: Plot Training Curves Comparison

fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Colors for each ablation
colors = {
    "baseline": "blue",
    "no_consistency": "orange",
    "global_only": "green",
    "no_confidence": "red",
}

# Plot 1: Total Loss
ax = axes[0, 0]
for abl_type, history in ablation_histories.items():
    ax.plot(history["train_loss"], label=abl_type, color=colors.get(abl_type, "gray"))
ax.axvline(x=15, color="gray", linestyle="--", alpha=0.5, label="Stage 2")
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.set_title("Total Training Loss")
ax.legend()
ax.grid(True, alpha=0.3)

# Plot 2: Global Loss
ax = axes[0, 1]
for abl_type, history in ablation_histories.items():
    ax.plot(history["train_global"], label=abl_type, color=colors.get(abl_type, "gray"))
ax.axvline(x=15, color="gray", linestyle="--", alpha=0.5)
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.set_title("Global Contrastive Loss")
ax.legend()
ax.grid(True, alpha=0.3)

# Plot 3: Local Loss
ax = axes[1, 0]
for abl_type, history in ablation_histories.items():
    ax.plot(history["train_local"], label=abl_type, color=colors.get(abl_type, "gray"))
ax.axvline(x=15, color="gray", linestyle="--", alpha=0.5)
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.set_title("Local Grounding Loss")
ax.legend()
ax.grid(True, alpha=0.3)

# Plot 4: Consistency Loss
ax = axes[1, 1]
for abl_type, history in ablation_histories.items():
    ax.plot(history["train_consist"], label=abl_type, color=colors.get(abl_type, "gray"))
ax.axvline(x=15, color="gray", linestyle="--", alpha=0.5)
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.set_title("Grounding Consistency Loss")
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(f"{ABLATION_CONFIG['output_base']}/training_curves.png", dpi=150)
plt.show()

print(f"Saved: {ABLATION_CONFIG['output_base']}/training_curves.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 15
#      13 # Plot 1: Total Loss
#      14 ax = axes[0, 0]
# ---> 15 for abl_type, history in ablation_histories.items():
#      16     ax.plot(history["train_loss"], label=abl_type, color=colors.get(abl_type, "gray"))
#      17 ax.axvline(x=15, color="gray", linestyle="--", alpha=0.5, label="Stage 2")
#
# NameError: name 'ablation_histories' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Cell 17: Evaluate Retrieval Metrics for All Ablations
from torch.utils.data import DataLoader
from clip4cad.data.gfa_dataset import gfa_collate_fn

# Create eval dataloader
eval_loader = DataLoader(
    ablation_val_dataset,
    batch_size=64,
    shuffle=False,
    num_workers=0,
    pin_memory=True,
    collate_fn=gfa_collate_fn,
)

ablation_results = {}

for abl_type, trainer in ablation_trainers.items():
    print(f"\nEvaluating: {abl_type}")
    results = trainer.evaluate_retrieval(eval_loader)
    ablation_results[abl_type] = results

    # Print key metrics
    if "Text→BRep" in results:
        r1 = results["Text→BRep"]["R@1"]
        r5 = results["Text→BRep"]["R@5"]
        print(f"  Text→BRep: R@1={r1:.4f}, R@5={r5:.4f}")

print("\n" + "="*80)
print("ABLATION RESULTS COMPARISON")
print("="*80)
print(f"\n{'Ablation':<20} {'R@1':<10} {'R@5':<10} {'R@10':<10} {'mAP@1':<10} {'mAP@5':<10}")
print("-"*70)

for abl_type, results in ablation_results.items():
    if "Text→BRep" in results:
        m = results["Text→BRep"]
        print(f"{abl_type:<20} {m['R@1']:<10.4f} {m['R@5']:<10.4f} {m['R@10']:<10.4f} "
            f"{m['mAP@1']:<10.4f} {m['mAP@5']:<10.4f}")

# Save results
import json
results_path = Path(ABLATION_CONFIG["output_base"]) / "ablation_results.json"
results_path.parent.mkdir(parents=True, exist_ok=True)
with open(results_path, "w") as f:
    json.dump(ablation_results, f, indent=2)
print(f"\nResults saved to: {results_path}")

# %%
# Cell 18: Cleanup (Optional - run when done to free memory)

# Clean up trainers
for abl_type, trainer in ablation_trainers.items():
    trainer.cleanup()

# Close datasets
ablation_train_dataset.close()
ablation_val_dataset.close()

print("Memory cleaned up!")
